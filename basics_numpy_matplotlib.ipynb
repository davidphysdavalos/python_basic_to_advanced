# %% [markdown]
# ## Importing libraries

# %%
import numpy as np
import scipy as sci
import matplotlib.pyplot as plt

# %% [markdown]
# ## Basic statements

# %%
# All possible statements in python
# https://www.programiz.com/python-programming/statements-structure

# Python program to illustrate
# If statement
i = 10
if (i > 15):
    print ("10 is less than 15")
print ("I am Not in if")

# Python program to illustrate
# if-else statement
i = 20
if (i < 15):
    print ("i is smaller than 15")
    print ("i'm in if Block")
else:
    print ("i is greater than 15")
    print ("i'm in else Block")
print ("i'm not in if and not in else Block")

# Python program to illustrate
# Nested - if statement
i = 10
if (i == 10):
    # First if statement
    if (i < 15):
        print ("i is smaller than 15")
    # Nested - if statement
    # Will only be executed if statement above
    # it is true
    if (i < 12):
        print ("i is smaller than 12 too")
    else:
        print ("i is greater than 15")
else:
    print ("i is not equal to 10")

# Python program to illustrate
# if-elif-else ladder
i = 20
if (i == 10):
    print ("i is 10")
elif (i == 15):
    print ("i is 15")
elif (i == 20):
    print ("i is 20")
else:
    print ("i is not present")

# Python program to illustrate
# Short Hand If
i = 10
if (i < 15): print ("i is smaller than 15")

# Python program to illustrate
# Short Hand If ... Else
i = 20
print ("i is 10") if (i == 10) else print ("i is not 10")

# Python program to illustrate
# Logical operators
a = True
b = False
print ('a and b is', a and b)
print ('a or b is', a or b)
print ('not a is', not a)

# Python program to illustrate
# bitwise operators
a = 10
b = 4
# Print bitwise AND operation
print ("a & b = ", a & b)
# Print bitwise OR operation
print ("a | b = ", a | b)
# Print bitwise NOT operation
print ("~a = ", ~a)
# print bitwise XOR operation
print ("a ^ b = ", a ^ b)
# print bitwise right shift operation
print ("a >> 2 = ", a >> 2)
# print bitwise left shift operation
print ("a << 2 = ", a << 2)

# Python program to illustrate
# Membership operators in Python
x = 'Geeks for Geeks'
y = {3:'a',4:'b'}
print('G' in x)
print('geeks' not in x)
print('Geeks' not in x)
print(3 in y)
print('b' in y)

# Python program to illustrate
# Identity operators
a1 = 3
b1 = 3
a2 = 'GeeksforGeeks'
b2 = 'GeeksforGeeks'
a3 = [1,2,3]
b3 = [1,2,3]
print (a1 is not b1)
print (a2 is b2)
print (a3 is b3)

# Python program to illustrate
# Loops
# While loop example
count = 0
while (count < 3):
    count = count + 1
    print("Hello Geek")
print()

# For loop example
for i in range(1, 11):
    print(i, end = ' ')
print()

# Python program to illustrate
# Iterating over a list
print("List Iteration")
l = ["geeks", "for", "geeks"]
for i in l:
    print(i)
print()

# Python program to illustrate
# Iterating over a tuple (immutable)
print("Tuple Iteration")
t = ("geeks", "for", "geeks")
for i in t:
    print(i)
print()

# Python program to illustrate
# Iterating over a String
print("String Iteration")
s = "Geeks"
for i in s :
    print(i)
print()

# Python program to illustrate
# Iterating over dictionary
print("Dictionary Iteration")
d = dict()
d['xyz'] = 123
d['abc'] = 345
for i in d :
    print("%s  %d" %(i, d[i]))
print()

# Python program to illustrate
# Iterating by index
print("Iterating by index")
l = ["geeks", "for", "geeks"]
for i in range(len(l)):
    print(l[i])
print()

# Python program to illustrate
# Iterating over a list using enumerate()
print("List Iteration using enumerate()")
l1 = ["geeks", "for", "geeks"]
for i, j in enumerate(l1):
    print(i, j)
print()

# Python program to illustrate
# Iterating over a list multiple values
print("Accessing index and value of list simultaneously")
l2 = ["geeks", "for", "geeks"]
for index, value in enumerate(l2):
    print(index, value)
print()
